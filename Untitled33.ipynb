# %% [markdown]
# <a href="https://colab.research.google.com/github/Lakshminarayan566/agriculture-advisory/blob/main/Untitled33.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 2.9 MB/s eta 0:00:00
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1

# %%
import PyPDF2

def extract_text_from_pdf(pdf_path):
    """
    Extracts text from all pages of a PDF file.
    """
    extracted_text = ""

    with open(pdf_path, "rb") as file:
        reader = PyPDF2.PdfReader(file)

        for page in reader.pages:
            page_text = page.extract_text()
            if page_text:
                extracted_text += page_text

    return extracted_text

# %%
pdf_path = "/content/M.Lucky(1).pdf"
text = extract_text_from_pdf(pdf_path)

print(text)
# Out:
# MARIDI LAKSHMI NARAYANA
# Student of AI&ML
# phone: 9704592449 | Email: luckymaridis@gmail.com | Location: Bhimavarm, Andhra Pradesh
# ABOUT ME
# EDUCATION
# VISHNU INSTITUTE OF
# TECHNOLOGY,BHIMAVARAM
# Bachelor of Technology
# course:AI&ML CGPA: 8.7
# 2024-2027
# LANGUAGESTECHNICAL SKILLSPROJECTS
# NPTEL COURSESACHIEVEMENTSCourse: MPC
# Percentage: 97.1
# 2021-2023
# HTML & CSS
# Java Script
# Python
# OOPS through Java
# MySQL,CQL
# Basics of React.js &
# Node.js
# Algorithm Analysis
# Machine Learning
# Database Management Systems
# Programming in Java
# Machine Learning Applications for Engineering
# and SciencesDeveloped a heart disease prediction model using
# ML techniques with key risk factor analysis and
# optimized data processing for accurate early
# diagnosis.
# Developed an AI-powered agricultural advisory
# system using Flask, Scikit-learn, and TensorFlow to
# provide data-driven farming recommendations for
# improved crop yield and efficiency.Aspiring Web Developer and AIML Engineering student with a strong foundation in HTML,
# CSS, and JavaScript. Passionate about building responsive and dynamic websites while
# exploring the intersection of web development and AI/ML technologies. Quick learner
# with problem-solving skills, eager to gain hands-on experience through an internship
# and contribute to real-world web projects.
# Developed a real-time chat app with video/audio
# calls using WebRTC, Socket.io, and Node.js,
# ensuring seamless communication with a
# responsive UI and efficient backend.MPS JUNIOR COLLEGE,MANDAPETA
# AI-POWERED AGRICULTURAL ADVISORY SYSTEM
# REAL-TIME CHAT APPLICATION WITH VIDEO & AUDIO CALLSHEART DISEASES RISK PREDICTION USING MACHINE LEARNING
# TECHNIQUES
# MANDAPETA PUBLIC SCHOOL
# Secondary Eduction
# CGPA: 10
# 2020- 2021
# Winner, AIML Department Paper Presentation
# Competition Presented a research paper on
# Hypertension Prediction using Machine Learning,
# showcasing innovative risk assessment techniques
# and strong research and presentation skills.
# Telugu
# Hindi
# English

# %%
from google import genai
client = genai.Client(api_key="AIzaSyBLBfg5zADhf2_xFLTs7esTIDoS6raviEc")

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=f'here is the context:{text} question: give rate about my resume 100'
)

print(response.text)
# Out:
# Okay, MARIDI LAKSHMI NARAYANA, you have a solid foundation with impressive projects and a notable achievement for a student! However, there are some key areas for improvement, especially regarding clarity and presentation.
#
# Here's my rate and detailed feedback:
#
# ## Resume Rating: **72/100**
#
# **Strengths:**
#
# *   **Excellent Projects:** Your projects are strong, relevant, well-described with technologies used, and showcase both AI/ML and web development skills. This is a huge plus for a student.
# *   **Notable Achievement:** Winning the AIML Department Paper Presentation Competition is a significant accomplishment and highlights research, presentation, and technical skills.
# *   **Relevant Skills:** You list a good range of technical skills that align with your "About Me" section (HTML, CSS, JS, Python, ML, Databases, React/Node basics).
# *   **Clear "About Me":** It clearly states your aspirations and key strengths.
# *   **NPTEL Courses:** Listing relevant NPTEL courses shows initiative and a commitment to learning.
# *   **Contact Information:** All necessary contact details are present and clear.
#
# **Areas for Improvement:**
#
# 1.  **Formatting and Readability (Biggest Issue):**
#     *   **Too Dense/Crowded:** The resume feels very packed. There's not enough white space, making it harder to scan quickly.
#     *   **Font Size:** The font size appears small, which can strain a recruiter's eyes.
#     *   **Suggestions:** Increase line spacing slightly, ensure good margins, and consider a slightly larger font for body text. You might need to make some descriptions more concise to achieve this.
#
# 2.  **Education Dates - B.Tech (Crucial Clarity Issue):**
#     *   "VISHNU INSTITUTE OF TECHNOLOGY... 2024-2027" is confusing. If you are *currently* pursuing your B.Tech and are expected to graduate in 2027, it should be listed as "2023 - Present (Expected Graduation: 2027)" or "Expected Graduation: 2027". As it stands, it looks like you are enrolling *this year* for a 3-year B.Tech, which is uncommon in India for AI&ML. Please clarify this.
#
# 3.  **Technical Skills Wording:**
#     *   **"Basics of React.js & Node.js":** Avoid diminishing your skills. Simply list them as "React.js, Node.js". If you've worked with them in projects, you know them.
#
# 4.  **NPTEL Courses (Add Impact):**
#     *   For the NPTEL courses, if you scored well, consider adding your grade/percentage to show your proficiency (e.g., "Programming in Java (Elite, 95%)").
#
# 5.  **"About Me" Focus (Minor):**
#     *   The sentence "Aspiring Web Developer and AIML Engineering student..." is good, but consider the primary role you're applying for. If it's more AI/ML focused, you might rephrase to put AI/ML first, and vice-versa. Or ensure your target role uses both skills.
#
# 6.  **Projects (Optional Enhancement):**
#     *   If possible, include links to your GitHub repositories or live demos for your projects. This allows recruiters to directly see your code and work.
#
# 7.  **Contact Info (Minor Refinement):**
#     *   The label "phone:" is redundant. You can just put "9704592449".
#
# **Overall Impression:**
#
# You have strong technical capabilities and have taken proactive steps like NPTEL courses and paper presentations, which is commendable. Your projects are particularly impressive for a student. The main hurdle for this resume is its presentation – making it easier to read and immediately understand the education timeline will significantly boost its impact.
#
# Good luck with your applications!

# %%
def resume_parser(input):
  prompt=f"""
  your resume parser
  Extract:
  -Executive Summary
  -Skills
  -Education
  -Tools & Techonolgies
  -Experience Summary

  Resume:
  {input}
  return in bullet points
  """
  response = client.models.generate_content(
          model = "gemini-2.5-flash",
          contents = prompt
  )
  return response.text

lucky = resume_parser(text)
print(lucky)
# Out:
# Here is the extracted information from the resume:
#
# ### Executive Summary
#
# *   Aspiring Web Developer and AIML Engineering student with a strong foundation in HTML, CSS, and JavaScript.
# *   Passionate about building responsive and dynamic websites while exploring the intersection of web development and AI/ML technologies.
# *   Quick learner with problem-solving skills, eager to gain hands-on experience through an internship and contribute to real-world web projects.
#
# ### Skills
#
# *   **Programming Languages:** HTML, CSS, JavaScript, Python, OOPS through Java
# *   **Databases:** MySQL, CQL
# *   **Web Technologies:** Basics of React.js & Node.js
# *   **AI/ML:** Algorithm Analysis, Machine Learning, Machine Learning Applications for Engineering and Sciences
# *   **Other Technical:** Database Management Systems, Programming in Java
# *   **Languages:** Telugu, Hindi, English
#
# ### Education
#
# *   **VISHNU INSTITUTE OF TECHNOLOGY, BHIMAVARAM**
#     *   Bachelor of Technology (AI&ML)
#     *   CGPA: 8.7
#     *   2024-2027
# *   **MPS JUNIOR COLLEGE, MANDAPETA**
#     *   Course: MPC
#     *   Percentage: 97.1
#     *   2021-2023
# *   **MANDAPETA PUBLIC SCHOOL**
#     *   Secondary Education
#     *   CGPA: 10
#     *   2020-2021
#
# ### Tools & Technologies
#
# *   HTML & CSS
# *   JavaScript
# *   Python
# *   Java (for OOPS & Programming)
# *   MySQL, CQL
# *   React.js
# *   Node.js
# *   Flask
# *   Scikit-learn
# *   TensorFlow
# *   WebRTC
# *   Socket.io
#
# ### Experience Summary
#
# *   Developed a heart disease prediction model using ML techniques, focusing on key risk factor analysis and optimized data processing for accurate early diagnosis.
# *   Developed an AI-powered agricultural advisory system using Flask, Scikit-learn, and TensorFlow to provide data-driven farming recommendations for improved crop yield and efficiency.
# *   Developed a real-time chat app with video/audio calls using WebRTC, Socket.io, and Node.js, ensuring seamless communication with a responsive UI and efficient backend.

# %%
def ats_match(parsed_resume, parsed_jd):
    prompt = f"""
You are an Applicant Tracking System.

Compare the resume and job description.

Resume:
{parsed_resume}

Job Description:
{parsed_jd}

Provide:
1. Match percentage (0-100)
2. Matching skills
3. Missing skills
4. Strengths
5. Improvement suggestions
"""
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=prompt
    )
    return response.text

# %%
ats_result = ats_match(lucky, luckyy)

print("===== ATS MATCH RESULT =====")
print(ats_result)
# Out:
# ===== ATS MATCH RESULT =====
# As an Applicant Tracking System, I have compared the provided resume against the job description.
#
# **Important Note:** The text provided for the "Job Description" appears to be almost identical to the "Resume" content, with only one additional experience bullet point in the "Job Description" section. I will proceed with the comparison assuming the second block of text, despite its header, represents the *target profile or job description* we are matching the resume against, especially noting the additional experience point in the 'JD' section.
#
# ---
#
# ### Comparison Results:
#
# 1.  **Match Percentage:** 90%
#
# 2.  **Matching Skills & Qualifications:**
#     *   HTML & CSS
#     *   JavaScript
#     *   Python
#     *   OOPS (through Java) / Programming in Java
#     *   MySQL, CQL
#     *   React.js (Basics acknowledged)
#     *   Node.js (Basics acknowledged)
#     *   Flask
#     *   Scikit-learn
#     *   TensorFlow
#     *   WebRTC
#     *   Socket.io
#     *   Algorithm Analysis
#     *   Machine Learning
#     *   Database Management Systems
#     *   Machine Learning Applications for Engineering and Sciences
#     *   Telugu, Hindi, English (Languages)
#     *   Aspiring Web Developer
#     *   AIML Engineering student
#     *   Strong foundation in HTML, CSS, JavaScript
#     *   Passion for building responsive and dynamic websites
#     *   Interest in the intersection of web development and AI/ML technologies
#     *   Quick learner
#     *   Problem-solving skills
#     *   Eagerness for hands-on experience through an internship
#     *   Desire to contribute to real-world web projects
#     *   Experience in developing heart disease prediction models using ML techniques
#     *   Experience in key risk factor analysis and optimized data processing
#     *   Experience in developing an AI-powered agricultural advisory system
#     *   Experience with data-driven farming recommendations
#     *   Experience in developing a real-time chat app with video/audio calls
#     *   Experience with seamless communication and responsive UI/efficient backend
#
# 3.  **Missing Skills & Qualifications:**
#     *   Experience as an "AIML Department Paper Presentation Competition Winner" (and associated details)
#     *   Specific experience or knowledge in "Hypertension Prediction using Machine Learning"
#     *   Explicit mention of "innovative risk assessment techniques" (beyond general ML project work)
#     *   Explicitly stated "strong research skills" (implied by projects, but not listed as a skill)
#     *   Explicitly stated "strong presentation skills" (implied by projects, but not listed as a skill)
#
# 4.  **Strengths:**
#     *   **High Alignment:** The resume demonstrates an exceptional alignment with the target profile, matching almost all technical skills, programming languages, tools, and project experiences listed.
#     *   **Relevant Projects:** The candidate's experience summary directly showcases projects involving core technologies and concepts mentioned, such as ML models, Flask, Scikit-learn, TensorFlow, WebRTC, Socket.io, and Node.js.
#     *   **Strong Technical Foundation:** The candidate has a solid base in both web development (HTML, CSS, JavaScript, React.js, Node.js) and AI/ML (Python, Scikit-learn, TensorFlow, Algorithm Analysis).
#     *   **Clear Career Aspirations:** The executive summary clearly articulates the candidate's goals, matching the "aspiring web developer and AIML engineering student" profile.
#     *   **Academic Excellence:** High CGPA/percentages across all educational stages demonstrate a strong academic record.
#
# 5.  **Improvement Suggestions:**
#     *   **Incorporate Missing Experience:** If the candidate has participated in paper presentations or similar research activities (especially those related to AI/ML or risk prediction), they should explicitly add this to their "Experience Summary" or a dedicated "Awards/Publications" section.
#     *   **Highlight Research & Presentation Skills:** Even if not specifically a paper competition winner, if the candidate has conducted research or presented projects, they should explicitly list "Research Skills" and "Presentation Skills" in their 'Skills' section, providing context in their experience bullet points.
#     *   **Quantify Achievements:** For existing projects, quantify impact where possible (e.g., "achieved X% accuracy in prediction," "improved efficiency by Y%").
#     *   **Expand on "Basics" for Web Technologies:** While "Basics of React.js & Node.js" is mentioned, expanding on specific features or libraries used within these frameworks would strengthen their web development proficiency.
